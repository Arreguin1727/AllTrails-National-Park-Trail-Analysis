# %% [markdown]
# # AllTrails National Park Trail Analysis
#
# # Table of Contents:
#
# ## 01. Import Libraries
# ## 02. Import Data
# ## 03. Data Cleaning and Consistency Checks
# - Convert the length column from meters to miles
# - Convert the elevation column from meters to feet
# - Split geolocation to two columns 1) Longitude 2) Latitude
# - Create difficulty rating Definition
# - Create new difficulty rating column
# - Calcuate number of features and actitivies and create new columns to display
# - Remove combined geolocation column
# - Check the dataset for null values
# - Check the dataset for duplicates
# - Check the dataset for mixed data types
# - Check details of cleaned dataframe
#
# ## 04. Export Cleaned Dataframe

# %% [markdown]
# # 01. Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Data

# %%
# set path
path=r'/Users/aylaarreguin/10-04-2022 AllTrails National Park Trail Analysis/'

# %%
path
# Out:
# '/Users/aylaarreguin/10-04-2022 AllTrails National Park Trail Analysis/'

# %%
# Import Data
df=pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'AllTrails NP Data.csv'), index_col = False)

# %%
#Exploring the data- First 5 Rows
df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#               city_name state_name   country_name  \
# 0                Seward     Alaska  United States
# 1  Denali National Park     Alaska  United States
# 2                Seward     Alaska  United States
# 3  Denali National Park     Alaska  United States
# 4  Denali National Park     Alaska  United States
#
#                                 _geoloc  popularity     length  \
# 0  {'lat': 60.18852, 'lng': -149.63156}     24.8931  15610.598
# 1  {'lat': 63.73049, 'lng': -148.91968}     18.0311   6920.162
# 2    {'lat': 60.18879, 'lng': -149.631}     17.7821   2896.812
# 3    {'lat': 63.73661, 'lng': -148.915}     16.2674   3379.614
# 4  {'lat': 63.73319, 'lng': -148.89682}     12.5935  29772.790
#
#    elevation_gain  difficulty_rating    route_type  visitor_usage  avg_rating  \
# 0       1161.8976                  5  out and back            3.0         5.0
# 1        507.7968                  3  out and back            1.0         4.5
# 2         81.9912                  1  out and back            3.0         4.5
# 3        119.7864                  1          loop            2.0         4.5
# 4       1124.7120                  5  out and back            1.0         4.5
#
#    num_reviews                                           features  \
# 0          423  ['dogs-no', 'forest', 'river', 'views', 'water...
# 1          260  ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2          224  ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3          237  ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4          110  ['dogs-no', 'lake', 'views', 'wild-flowers', '...
#
#                                           activities units
# 0  ['birding', 'camping', 'hiking', 'nature-trips...     i
# 1  ['birding', 'camping', 'hiking', 'nature-trips...     i
# 2                              ['hiking', 'walking']     i
# 3  ['birding', 'hiking', 'nature-trips', 'trail-r...     i
# 4  ['birding', 'fishing', 'hiking', 'nature-trips...     i

# %%
df.shape
# Out:
# (3313, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   trail_id           3313 non-null   int64
#  1   name               3313 non-null   object
#  2   area_name          3313 non-null   object
#  3   city_name          3313 non-null   object
#  4   state_name         3313 non-null   object
#  5   country_name       3313 non-null   object
#  6   _geoloc            3313 non-null   object
#  7   popularity         3313 non-null   float64
#  8   length             3313 non-null   float64
#  9   elevation_gain     3313 non-null   float64
#  10  difficulty_rating  3313 non-null   int64
#  11  route_type         3313 non-null   object
#  12  visitor_usage      3060 non-null   float64
#  13  avg_rating         3313 non-null   float64
#  14  num_reviews        3313 non-null   int64
#  15  features           3313 non-null   object
#  16  activities         3313 non-null   object
#  17  units              3313 non-null   object
# dtypes: float64(5), int64(3), object(10)
# memory usage: 466.0+ KB

# %%
df.describe()
# Out:
#            trail_id   popularity         length  elevation_gain  \
# count  3.313000e+03  3313.000000    3313.000000     3313.000000
# mean   1.018506e+07     8.953441   17676.848717      641.805943
# std    1.503248e+05     8.138323   25497.376640      901.506642
# min    1.000001e+07     0.000000       0.000000        0.000000
# 25%    1.002853e+07     3.794100    4506.152000      116.738400
# 50%    1.023781e+07     6.573100   10621.644000      359.968800
# 75%    1.029234e+07    11.255600   21404.222000      833.932800
# max    1.054542e+07    84.622900  529794.728000    14029.944000
#
#        difficulty_rating  visitor_usage   avg_rating  num_reviews
# count        3313.000000    3060.000000  3313.000000  3313.000000
# mean            3.167824       1.877124     4.173106    70.341986
# std             1.702752       0.693641     0.947039   184.118370
# min             1.000000       1.000000     0.000000     0.000000
# 25%             1.000000       1.000000     4.000000     5.000000
# 50%             3.000000       2.000000     4.500000    17.000000
# 75%             5.000000       2.000000     4.500000    57.000000
# max             7.000000       4.000000     5.000000  3903.000000

# %% [markdown]
# # 02. Data Cleaning

# %%
# Create a new column to convert the length column from meters to miles and the elevation column from meters to feet
df['length_miles']=df['length'].apply(lambda x : x*0.000621371)
df['elevation_gain_feet']=df['elevation_gain'].apply(lambda x : x*3.28084)

# %%
#drop original length column and elevation_gain column 
df.drop(['length'], axis = 1, inplace = True)
df.drop(['elevation_gain'], axis =1, inplace = True)

# %%
#Split _geoloc to two columns 1) latitude and longtitude
## Create two new columns
df[['lat','lng']] = df['_geoloc'].apply(lambda x: pd.Series(str(x).split(",")))
df['lat'] = df['lat'].apply(lambda x: (x.split(':')[1].split()[-1])).astype(float)
df['lng'] = df['lng'].apply(lambda x: (x.split(':')[1].split()[-1][:-1])).astype(float)

# %%
# Rename the lat and lng column for easier readability 
df.rename(columns = {'lat' : 'latitude', 'lng' : 'longitude'}, inplace = True)

# %%
#remove geoloc variables
df.drop(['_geoloc'],axis = 1, inplace = True)

# %%
#Create difficulty_rating definition
def definition(difficulty_rate):
    
    if difficulty_rate == 1:
        return 'easy'
    elif difficulty_rate == 3:
        return 'moderate'
    elif difficulty_rate == 5:
        return 'hard'
    else:
        return 'hard'

# %%
# Create a new column of the difficulty rating definition
df['difficulty'] = df.apply(lambda x: definition(difficulty_rate = x['difficulty_rating']), axis = 1)

# %%
#Calcuate the number of features & actitivies based on the number listed in the feature and activities column
## Create two new columns with calculation 
df['features_count'] = df['features'].apply(lambda x: len(x.split(',')))
df['activities_count'] = df['activities'].apply(lambda x: len(x.split(',')))

# %%
# Check df
df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#               city_name state_name   country_name  popularity  \
# 0                Seward     Alaska  United States     24.8931
# 1  Denali National Park     Alaska  United States     18.0311
# 2                Seward     Alaska  United States     17.7821
# 3  Denali National Park     Alaska  United States     16.2674
# 4  Denali National Park     Alaska  United States     12.5935
#
#    difficulty_rating    route_type  visitor_usage  ...  \
# 0                  5  out and back            3.0  ...
# 1                  3  out and back            1.0  ...
# 2                  1  out and back            3.0  ...
# 3                  1          loop            2.0  ...
# 4                  5  out and back            1.0  ...
#
#                                             features  \
# 0  ['dogs-no', 'forest', 'river', 'views', 'water...
# 1  ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2  ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3  ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4  ['dogs-no', 'lake', 'views', 'wild-flowers', '...
#
#                                           activities units length_miles  \
# 0  ['birding', 'camping', 'hiking', 'nature-trips...     i     9.699973
# 1  ['birding', 'camping', 'hiking', 'nature-trips...     i     4.299988
# 2                              ['hiking', 'walking']     i     1.799995
# 3  ['birding', 'hiking', 'nature-trips', 'trail-r...     i     2.099994
# 4  ['birding', 'fishing', 'hiking', 'nature-trips...     i    18.499948
#
#   elevation_gain_feet  latitude  longitude  difficulty  features_count  \
# 0         3812.000122  60.18852 -149.63156        hard               7
# 1         1666.000053  63.73049 -148.91968    moderate               5
# 2          269.000009  60.18879 -149.63100        easy               4
# 3          393.000013  63.73661 -148.91500        easy               7
# 4         3690.000118  63.73319 -148.89682        hard               5
#
#   activities_count
# 0                5
# 1                5
# 2                2
# 3                5
# 4                5
#
# [5 rows x 22 columns]

# %% [markdown]
# With research, I was unable to find the metedata for the visitor usage column. I believe this was an old feature, since the dataset was extracted from All-Trials API. My guess is that it is not updated anymore, therefore, many trails have a null value. This feature is not important for my analysis so I will drop this column.

# %%
#drop visitor_usage column 
df.drop(['visitor_usage'],axis = 1, inplace = True)

# %%
#drop units column because it has no usable data for my analysis 
df.drop(['units'],axis = 1, inplace = True)

# %%
#Review and check the dataset
df.isnull().sum()
# Out:
# trail_id               0
# name                   0
# area_name              0
# city_name              0
# state_name             0
# country_name           0
# popularity             0
# difficulty_rating      0
# route_type             0
# avg_rating             0
# num_reviews            0
# features               0
# activities             0
# length_miles           0
# elevation_gain_feet    0
# latitude               0
# longitude              0
# difficulty             0
# features_count         0
# activities_count       0
# dtype: int64

# %%
#Checking for duplicates
duplicate = df[df.duplicated()]

# %%
duplicate
# Out:
# Empty DataFrame
# Columns: [trail_id, name, area_name, city_name, state_name, country_name, popularity, difficulty_rating, route_type, avg_rating, num_reviews, features, activities, length_miles, elevation_gain_feet, latitude, longitude, difficulty, features_count, activities_count]
# Index: []

# %%
# check for mixed data type
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %%
# Check details of cleaned dataframe 
df.shape
# Out:
# (3313, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3313 entries, 0 to 3312
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   trail_id             3313 non-null   int64
#  1   name                 3313 non-null   object
#  2   area_name            3313 non-null   object
#  3   city_name            3313 non-null   object
#  4   state_name           3313 non-null   object
#  5   country_name         3313 non-null   object
#  6   popularity           3313 non-null   float64
#  7   difficulty_rating    3313 non-null   int64
#  8   route_type           3313 non-null   object
#  9   avg_rating           3313 non-null   float64
#  10  num_reviews          3313 non-null   int64
#  11  features             3313 non-null   object
#  12  activities           3313 non-null   object
#  13  length_miles         3313 non-null   float64
#  14  elevation_gain_feet  3313 non-null   float64
#  15  latitude             3313 non-null   float64
#  16  longitude            3313 non-null   float64
#  17  difficulty           3313 non-null   object
#  18  features_count       3313 non-null   int64
#  19  activities_count     3313 non-null   int64
# dtypes: float64(6), int64(5), object(9)
# memory usage: 517.8+ KB

# %%
df.describe()
# Out:
#            trail_id   popularity  difficulty_rating   avg_rating  num_reviews  \
# count  3.313000e+03  3313.000000        3313.000000  3313.000000  3313.000000
# mean   1.018506e+07     8.953441           3.167824     4.173106    70.341986
# std    1.503248e+05     8.138323           1.702752     0.947039   184.118370
# min    1.000001e+07     0.000000           1.000000     0.000000     0.000000
# 25%    1.002853e+07     3.794100           1.000000     4.000000     5.000000
# 50%    1.023781e+07     6.573100           3.000000     4.500000    17.000000
# 75%    1.029234e+07    11.255600           5.000000     4.500000    57.000000
# max    1.054542e+07    84.622900           7.000000     5.000000  3903.000000
#
#        length_miles  elevation_gain_feet     latitude   longitude  \
# count   3313.000000          3313.000000  3313.000000  3313.00000
# mean      10.983881          2105.662609    39.671520  -106.38817
# std       15.843330          2957.699051     5.870789    17.75683
# min        0.000000             0.000000    19.086090  -156.25357
# 25%        2.799992           383.000012    36.335580  -118.77161
# 50%        6.599982          1181.000038    38.468380  -110.79927
# 75%       13.299963          2736.000088    44.320420  -101.92792
# max      329.199080         46030.001473    63.883740   -68.03679
#
#        features_count  activities_count
# count     3313.000000       3313.000000
# mean         4.930878          4.012979
# std          1.868662          1.687411
# min          1.000000          1.000000
# 25%          4.000000          3.000000
# 50%          5.000000          4.000000
# 75%          6.000000          5.000000
# max         12.000000         12.000000

# %%
df.head()
# Out:
#    trail_id                        name                   area_name  \
# 0  10020048     Harding Ice Field Trail  Kenai Fjords National Park
# 1  10236086  Mount Healy Overlook Trail        Denali National Park
# 2  10267857          Exit Glacier Trail  Kenai Fjords National Park
# 3  10236076        Horseshoe Lake Trail        Denali National Park
# 4  10236082          Triple Lakes Trail        Denali National Park
#
#               city_name state_name   country_name  popularity  \
# 0                Seward     Alaska  United States     24.8931
# 1  Denali National Park     Alaska  United States     18.0311
# 2                Seward     Alaska  United States     17.7821
# 3  Denali National Park     Alaska  United States     16.2674
# 4  Denali National Park     Alaska  United States     12.5935
#
#    difficulty_rating    route_type  avg_rating  num_reviews  \
# 0                  5  out and back         5.0          423
# 1                  3  out and back         4.5          260
# 2                  1  out and back         4.5          224
# 3                  1          loop         4.5          237
# 4                  5  out and back         4.5          110
#
#                                             features  \
# 0  ['dogs-no', 'forest', 'river', 'views', 'water...
# 1  ['dogs-no', 'forest', 'views', 'wild-flowers',...
# 2  ['dogs-no', 'partially-paved', 'views', 'wildl...
# 3  ['dogs-no', 'forest', 'lake', 'kids', 'views',...
# 4  ['dogs-no', 'lake', 'views', 'wild-flowers', '...
#
#                                           activities  length_miles  \
# 0  ['birding', 'camping', 'hiking', 'nature-trips...      9.699973
# 1  ['birding', 'camping', 'hiking', 'nature-trips...      4.299988
# 2                              ['hiking', 'walking']      1.799995
# 3  ['birding', 'hiking', 'nature-trips', 'trail-r...      2.099994
# 4  ['birding', 'fishing', 'hiking', 'nature-trips...     18.499948
#
#    elevation_gain_feet  latitude  longitude difficulty  features_count  \
# 0          3812.000122  60.18852 -149.63156       hard               7
# 1          1666.000053  63.73049 -148.91968   moderate               5
# 2           269.000009  60.18879 -149.63100       easy               4
# 3           393.000013  63.73661 -148.91500       easy               7
# 4          3690.000118  63.73319 -148.89682       hard               5
#
#    activities_count
# 0                 5
# 1                 5
# 2                 2
# 3                 5
# 4                 5

# %% [markdown]
# # Export Cleaned Dataframe

# %%
# Export cleaned dataframe 
df.to_csv(os.path.join(path,'Data', 'Prepared Data','AllTrails_cleaned.csv'))
